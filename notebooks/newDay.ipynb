# %% [markdown]
# 24-01-26

# %%
import matplotlib.pyplot as plt  # noqa: F401
import numpy as np
# %matplotlib inline

# %%
x = np.array(['Q1', 'Q2', 'Q3', 'Q4'])
y = np.array([234,254,345,456])
plt.bar(x, y, color = 'purple')
plt.show()

# %%
x = np.random.randn(1000)
plt.hist(x, bins=20,color = 'green',density=True)
plt.show()

# %%
x = np.random.randn(1000)
plt.hist(x, bins=20,color = 'green')
plt.show()

# %%
x = np.random.randn(1000)
plt.hist(x, bins=100,color = 'green', density=True,alpha=0.4)
plt.show()

# %%
x = np.random.randn(10000)*10+30
y = np.random.randn(10000)*10+50
z = np.random.randn(10000)*10+10

plt.boxplot([x,y,z], 0, vert = False)
plt.title('Box plot')
plt.show()
# Out:
# C:\Users\vedas\AppData\Local\Temp\ipykernel_15776\3788229361.py:5: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.boxplot([x,y,z], 0, vert = False)

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y,color='orange',linewidth=2)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave')
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y,color='orange',linestyle = ':',linewidth=2)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave')
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y,color='orange',linestyle = '-.',linewidth=2)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave')
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y,color='red',linestyle='--',linewidth=2)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave')
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y,color='orange',drawstyle = 'steps',linewidth=2)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave')
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y,color='orange',linestyle = '-',linewidth=2)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave')
plt.xlim([0,5])
plt.ylim([-2,+2])
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y,color='orange',linestyle='none',linewidth=2,markersize=5,marker='.')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave')
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y,color="#000000",linestyle='none',linewidth=2,markersize=5,marker='.')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave')
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y,color="#000000",linestyle='none',linewidth=2,markersize=5,marker='o', markerfacecolor='grey', markeredgewidth=1, markeredgecolor='black')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave')
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.scatter(x,y,color="#000000",linewidth=2,s=25,marker='o', edgecolor='black')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot of Sine Wave')
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.scatter(x,y,color="#000000",linewidth=2,s=25,marker='^', edgecolor='black')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.xlim([0,10])
plt.title('Scatter Plot of Sine Wave')
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
z = np.cos(x) 
print(x)
print(y)
print(z)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
#create a figure object
fig0 = plt.figure()
axes0 = fig0.add_axes([0,0,1,1])
axes0.plot(x,y,color='red', linewidth=2)
axes0.set_xlabel('X-axis')
axes0.set_ylabel('Y-axis')
axes0.set_title('Line Plot')
plt.show()

# %%
fig0 = plt.figure(figsize=(5,1))
axes0 = fig0.add_axes([0,0,1,1])
axes0.plot(x,y,color='red', linewidth=2)
axes0.set_xlabel('X-axis')
axes0.set_ylabel('Y-axis')
axes0.set_title('Line Plot')
plt.show()

# %%
fig0 = plt.figure(figsize=(5,2), dpi = 100)
axes0 = fig0.add_axes([0,0,1,1])
axes0.plot(x,y,color='orange', linestyle='-', linewidth=2,label='Sine Wave')
axes0.plot(x,z,color='red', linestyle='-', linewidth=2,label='Cosine Wave')
axes0.legend(loc=0)
axes0.set_xlabel('X-axis')
axes0.set_ylabel('Y-axis')
axes0.set_title('Line Plot')
plt.show()

# %%
import os
os.chdir(r"D:\SEM VI\NCDL")
os.getcwd()
fig0.savefig('lineplot.pdf')

# %%
fig0 = plt.figure(figsize=(8,3), dpi = 80)
axes1 = fig0.add_axes([0,0,0.3,1])
axes2 = fig0.add_axes([0.5,0,0.3,1])
axes1.plot(x,y,color='orange', linestyle='-', linewidth=2,label='Sine Wave')
axes2.plot(x,z,color='red', linestyle='-', linewidth=2,label='Cosine Wave')
axes1.set_title('Sine Wave')
axes2.set_title('Cosine Wave')
axes1.set_xlabel('X-axis')
axes1.set_ylabel('Y-axis')
axes2.set_xlabel('X-axis')
axes2.set_ylabel('Y-axis')
plt.show()

# %%
fig0 = plt.figure(figsize=(8,4), dpi = 80)
axes1 = fig0.add_axes([0,0.8,0.2,0.5])
axes2 = fig0.add_axes([0,0,0.2,0.5])
axes1.plot(x,y,marker='o', color='orange', linestyle='-', linewidth=2,label='Sine Wave')
axes2.plot(x,z,marker='s', color='red', linestyle='-', linewidth=2,label='Cosine Wave')
axes1.set_title('Sine Wave')
axes2.set_title('Cosine Wave')
axes1.set_xlabel('X-axis')
axes1.set_ylabel('Y-axis')
axes2.set_xlabel('X-axis')
axes2.set_ylabel('Y-axis')
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(6,6), dpi=80)
c = np.random.randn(10000)
axes[0,0].hist(c, bins=100, color='green', density=True,alpha=0.7)
axes[0,0].set_title('Histogram')

axes[1,1].plot(x,y,color='orange', linestyle='-', linewidth=2,label='Sine Wave')
axes[1,1].set_title('Sine Wave')
axes[1,1].set_xlabel('X-axis')
axes[1,1].set_ylabel('Y-axis')

axes[1,0].plot(x,z,color='red', linestyle='-', linewidth=2,label='Cosine Wave')
axes[1,0].set_title('Cosine Wave')
axes[1,0].set_xlabel('X-axis')
axes[1,0].set_ylabel('Y-axis')

a = np.array(['Q1', 'Q2', 'Q3', 'Q4'])
b = np.array([234,254,345,456])
axes[0,1].bar(a, b, color = 'purple')
axes[0,1].set_title('Bar Plot')


axes[1,1].set_xlabel('X-axis')
axes[1,1].set_ylabel('Y-axis')
plt.tight_layout()
plt.show()

# %%
fig.savefig('subplots.png')

# %%
os.chdir(r"D:\SEM VI\NCDL")
os.getcwd()
import pandas as pd
df = pd.read_csv('data_iris.csv')

# %%
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.loc[:,'Petal.Length'].plot.hist(bins=30, color='purple', alpha=0.7)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.loc[:,'Petal.Length'].plot.hist(bins=50, color='orange', alpha=0.7)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.loc[:,['Petal.Length','Sepal.Length']].plot.hist(bins=50, alpha=0.7, color=['purple','orange'])
# Out:
# <Axes: ylabel='Frequency'>

# %%
frequenices = df.Species.value_counts()
my_counts = list(frequenices.values)
my_labels = list(frequenices.index)
df2 = pd.DataFrame({'counts':my_counts,'labels':my_labels})
df2
# Out:
#    counts      labels
# 0      50      setosa
# 1      50  versicolor
# 2      50   virginica

# %%
df2.plot.bar(color=['orange'],alpha=0.7)
plt.show()

# %%
df.plot.scatter(x='Sepal.Length', y='Sepal.Width', color='green', alpha=0.7,s=100)
plt.show()

# %%
my_cols_dict = {'setosa':'red', 'versicolor':'blue', 'virginica':'green'}
my_cols_ = df['Species'].apply(lambda x: my_cols_dict[x])
pd.plotting.scatter_matrix(df, c=my_cols_, alpha=0.7, figsize=(10,10), diagonal='hist',s=100)
plt.show()

# %%
import seaborn as sns # noqa: F401
import warnings
warnings.filterwarnings('ignore')
